# %%
# %pip install dotenv
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, dotenv
#
#    ---------------------------------------- 2/2 [dotenv]
#
# Successfully installed dotenv-0.9.9 python-dotenv-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
print(os.environ['PINECONE_API_KEY'][:5] + '...')
print(os.environ['OPENAI_API_KEY'][:5] + '...')
# Out:
# pcsk_...
# sk-pr...

# %%
pinecone_api_key = os.environ['PINECONE_API_KEY']

# %%
# %pip install pinecone
# Out:
# Collecting pinecone
#   Downloading pinecone-7.0.2-py3-none-any.whl.metadata (9.5 kB)
# Collecting certifi>=2019.11.17 (from pinecone)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.6.1-py3-none-any.whl.metadata (27 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pinecone) (4.14.0)
# Collecting urllib3>=1.26.5 (from pinecone)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging<25.0,>=24.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (24.2)
# Collecting requests<3.0.0,>=2.32.3 (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone)
#   Using cached charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\api\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.10)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Downloading pinecone-7.0.2-py3-none-any.whl (516 kB)
# Downloading pinecone_plugin_assistant-1.6.1-py3-none-any.whl (239 kB)
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, pinecone-plugin-interface, charset-normalizer, certifi, requests, pinecone-plugin-assistant, pinecone
#
#    ----------- ---------------------------- 2/7 [charset-normalizer]
#    ---------------------------- ----------- 5/7 [pinecone-plugin-assistant]
#    ---------------------------- ----------- 5/7 [pinecone-plugin-assistant]
#    ---------------------------------- ----- 6/7 [pinecone]
#    ---------------------------------- ----- 6/7 [pinecone]
#    ---------------------------------- ----- 6/7 [pinecone]
#    ---------------------------------- ----- 6/7 [pinecone]
#    ---------------------------------- ----- 6/7 [pinecone]
#    ---------------------------------------- 7/7 [pinecone]
#
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 pinecone-7.0.2 pinecone-plugin-assistant-1.6.1 pinecone-plugin-interface-0.0.7 requests-2.32.3 urllib3-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec
# 객체 생성
pc = Pinecone(api_key=pinecone_api_key)

# %%
# %pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.19-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-core<1.0.0,>=0.3.63 (from langchain_openai)
#   Downloading langchain_core-0.3.63-py3-none-any.whl.metadata (5.8 kB)
# Collecting openai<2.0.0,>=1.68.2 (from langchain_openai)
#   Downloading openai-1.84.0-py3-none-any.whl.metadata (25 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Using cached tiktoken-0.9.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Collecting langsmith<0.4,>=0.1.126 (from langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Downloading langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting PyYAML>=5.3 (from langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (4.14.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.11.5)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached orjson-3.10.18-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.32.3)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached zstandard-0.23.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: anyio in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (4.9.0)
# Requirement already satisfied: certifi in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (2025.4.26)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.16.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.68.2->langchain_openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.68.2->langchain_openai)
#   Using cached jiter-0.10.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\user\miniconda3\envs\api\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.3.1)
# Collecting tqdm>4 (from openai<2.0.0,>=1.68.2->langchain_openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.63->langchain_openai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\miniconda3\envs\api\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.63->langchain_openai) (2.4.0)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain_openai)
#   Using cached regex-2024.11.6-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python313\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain_openai) (0.4.6)
# Downloading langchain_openai-0.3.19-py3-none-any.whl (64 kB)
# Downloading langchain_core-0.3.63-py3-none-any.whl (438 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.3.45-py3-none-any.whl (363 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading openai-1.84.0-py3-none-any.whl (725 kB)
#    ---------------------------------------- 0.0/725.5 kB ? eta -:--:--
#    --------------------------------------- 725.5/725.5 kB 36.9 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.10.0-cp313-cp313-win_amd64.whl (205 kB)
# Using cached orjson-3.10.18-cp313-cp313-win_amd64.whl (134 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tiktoken-0.9.0-cp313-cp313-win_amd64.whl (894 kB)
# Using cached zstandard-0.23.0-cp313-cp313-win_amd64.whl (495 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Using cached regex-2024.11.6-cp313-cp313-win_amd64.whl (273 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: zstandard, tqdm, tenacity, regex, PyYAML, orjson, jsonpointer, jiter, httpcore, distro, tiktoken, requests-toolbelt, jsonpatch, httpx, openai, langsmith, langchain-core, langchain_openai
#
#    ---- -----------------------------------  2/18 [tenacity]
#    -------- -------------------------------  4/18 [PyYAML]
#    ----------------- ----------------------  8/18 [httpcore]
#    -------------------------- ------------- 12/18 [jsonpatch]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    ------------------------------- -------- 14/18 [openai]
#    --------------------------------- ------ 15/18 [langsmith]
#    ----------------------------------- ---- 16/18 [langchain-core]
#    ----------------------------------- ---- 16/18 [langchain-core]
#    ----------------------------------- ---- 16/18 [langchain-core]
#    ----------------------------------- ---- 16/18 [langchain-core]
#    ------------------------------------- -- 17/18 [langchain_openai]
#    ---------------------------------------- 18/18 [langchain_openai]
#
# Successfully installed PyYAML-6.0.2 distro-1.9.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.10.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.63 langchain_openai-0.3.19 langsmith-0.3.45 openai-1.84.0 orjson-3.10.18 regex-2024.11.6 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.9.0 tqdm-4.67.1 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
index_name = 'sample-index'
model_name = 'text-embedding-3-small'
embedding_dim = 1536  # 모델이 지원하는 임베딩 차원하고 같게
# 인덱스 생성 - DB생성
if not pc.has_index(index_name):
    pc.create_index(name=index_name,
                    dimension=embedding_dim,
                    spec=ServerlessSpec(
                       cloud='aws',
                        region='us-east-1'
                    )
    )
# 인덱스 객체 연결
index = pc.Index(index_name)
# openAI의 임베딩 모델 설정(text-embedding-3-small)
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model = model_name)

# %%
# %pip install langchain_pinecone
# Out:
# Collecting langchain_pineconeNote: you may need to restart the kernel to use updated packages.
#
#   Downloading langchain_pinecone-0.2.8-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain_pinecone) (0.3.63)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (7.0.2)
# Collecting numpy>=1.26.4 (from langchain_pinecone)
#   Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting langchain-tests<1.0.0,>=0.3.7 (from langchain_pinecone)
#   Downloading langchain_tests-0.3.19-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-openai>=0.3.11 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain_pinecone) (0.3.19)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (4.14.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (2.11.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\miniconda3\envs\api\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (3.0.0)
# Collecting pytest<9,>=7 (from langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading pytest-8.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting pytest-asyncio<1,>=0.20 (from langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading pytest_asyncio-0.26.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (0.28.1)
# Collecting syrupy<5,>=4 (from langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading syrupy-4.9.1-py3-none-any.whl.metadata (38 kB)
# Collecting pytest-socket<1,>=0.6.0 (from langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading pytest_socket-0.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: anyio in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (4.9.0)
# Requirement already satisfied: certifi in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\miniconda3\envs\api\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (0.23.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (1.6.1)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (2.4.0)
# Collecting aiohttp>=3.9.0 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading aiohttp-3.12.9-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting aiohttp-retry<3.0.0,>=2.9.1 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (0.4.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\user\appdata\roaming\python\python313\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (0.4.6)
# Collecting iniconfig>=1 (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain_pinecone) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.34->langchain_pinecone) (3.4.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading frozenlist-1.6.2-cp313-cp313-win_amd64.whl.metadata (17 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading multidict-6.4.4-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading propcache-0.3.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone)
#   Downloading yarl-1.20.0-cp313-cp313-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-openai>=0.3.11->langchain_pinecone) (1.84.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\user\miniconda3\envs\api\lib\site-packages (from langchain-openai>=0.3.11->langchain_pinecone) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai>=0.3.11->langchain_pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\miniconda3\envs\api\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai>=0.3.11->langchain_pinecone) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\user\miniconda3\envs\api\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai>=0.3.11->langchain_pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\user\miniconda3\envs\api\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai>=0.3.11->langchain_pinecone) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\user\miniconda3\envs\api\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.3.11->langchain_pinecone) (2024.11.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain_pinecone) (1.17.0)
# Downloading langchain_pinecone-0.2.8-py3-none-any.whl (22 kB)
# Downloading langchain_tests-0.3.19-py3-none-any.whl (40 kB)
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading pytest-8.4.0-py3-none-any.whl (363 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading pytest_asyncio-0.26.0-py3-none-any.whl (19 kB)
# Downloading pytest_socket-0.7.0-py3-none-any.whl (6.8 kB)
# Downloading syrupy-4.9.1-py3-none-any.whl (52 kB)
# Downloading aiohttp-3.12.9-cp313-cp313-win_amd64.whl (445 kB)
# Downloading multidict-6.4.4-cp313-cp313-win_amd64.whl (38 kB)
# Downloading yarl-1.20.0-cp313-cp313-win_amd64.whl (92 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.6.2-cp313-cp313-win_amd64.whl (46 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
# Downloading propcache-0.3.1-cp313-cp313-win_amd64.whl (44 kB)
# Installing collected packages: propcache, pluggy, numpy, multidict, iniconfig, frozenlist, attrs, aiohappyeyeballs, yarl, pytest, aiosignal, syrupy, pytest-socket, pytest-asyncio, aiohttp, aiohttp-retry, langchain-tests, langchain_pinecone
#
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    -------- -------------------------------  4/18 [iniconfig]
#    -------------------- -------------------  9/18 [pytest]
#    -------------------- -------------------  9/18 [pytest]
#    -------------------- -------------------  9/18 [pytest]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [langchain-tests]
#    ---------------------------------------- 18/18 [langchain_pinecone]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.9 aiohttp-retry-2.9.1 aiosignal-1.3.2 attrs-25.3.0 frozenlist-1.6.2 iniconfig-2.1.0 langchain-tests-0.3.19 langchain_pinecone-0.2.8 multidict-6.4.4 numpy-2.2.6 pluggy-1.6.0 propcache-0.3.1 pytest-8.4.0 pytest-asyncio-0.26.0 pytest-socket-0.7.0 syrupy-4.9.1 yarl-1.20.0

# %%
# Doc 타입으로 데이터를 upset
from langchain_core.documents import Document
doc1 = Document(page_content="Building an exciting new project with LangChain - come check it out!",
                metadata={"source": "tweet"})
doc2 = Document(page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
                metadata={"source": "news"})
doc3 = Document(page_content="LangGraph is the best framework for building stateful, agentic applications!",
                metadata={"source": "tweet"})
# 벡터스토어 초기화
from langchain_pinecone import PineconeVectorStore
vector_store = PineconeVectorStore(index=index,embedding=embeddings)
vector_store.add_documents([doc1,doc2,doc3])
print(f'{index.describe_index_stats()}')
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 12
#      11 vector_store = PineconeVectorStore(index=index,embedding=embeddings)
# ---> 12 vector_store.add_documents([doc1,doc2,doc3])
#      13 print(f'{index.describe_index_stats()}')
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)
#     212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)
#     100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)
#     344     ),
#     345 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)
#     144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:38, in raise_exceptions_or_return(r)
#      37 if r.status == 401:
# ---> 38     raise UnauthorizedException(http_resp=r)
#      40 if r.status == 403:
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 05 Jun 2025 07:49:51 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized
#
#
# The above exception was the direct cause of the following exception:
#
# UnauthorizedException                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 12
#      11 vector_store = PineconeVectorStore(index=index,embedding=embeddings)
# ---> 12 vector_store.add_documents([doc1,doc2,doc3])
#      13 print(f'{index.describe_index_stats()}')
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)
#     212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)
#     100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)
#     344     ),
#     345 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)
#     144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:38, in raise_exceptions_or_return(r)
#      37 if r.status == 401:
# ---> 38     raise UnauthorizedException(http_resp=r)
#      40 if r.status == 403:
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 05 Jun 2025 07:49:51 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized
#
#
# The above exception was the direct cause of the following exception:
#
# UnauthorizedException                     Traceback (most recent call last)
# Cell In[16], line 12
#      10 from langchain_pinecone import PineconeVectorStore
#      11 vector_store = PineconeVectorStore(index=index,embedding=embeddings)
# ---> 12 vector_store.add_documents([doc1,doc2,doc3])
#      13 print(f'{index.describe_index_stats()}')
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     286     texts = [doc.page_content for doc in documents]
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#     293 raise NotImplementedError(msg)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     319     embeddings = self._embedding.embed_documents(chunk_texts)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     181     raise ValueError(
#     182         "async_req is not supported when batch_size is provided."
#     183         "To upsert in parallel, please follow: "
#     184         "https://docs.pinecone.io/docs/insert-data#sending-upserts-in-parallel"
#     185     )
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#     191     raise ValueError("batch_size must be a positive integer")
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)
#     212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)
#     100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     673 kwargs = self._process_openapi_kwargs(kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)
#     129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)
#     302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)
#     344     ),
#     345 )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)
#     383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)
#     403         body=body,
#     404     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)
#     144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\Users\USER\miniconda3\envs\api\Lib\site-packages\pinecone\openapi_support\rest_utils.py:38, in raise_exceptions_or_return(r)
#      36 if not 200 <= r.status <= 299:
#      37     if r.status == 401:
# ---> 38         raise UnauthorizedException(http_resp=r)
#      40     if r.status == 403:
#      41         raise ForbiddenException(http_resp=r)
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 05 Jun 2025 07:49:51 GMT', 'Content-Type': 'text/plain', 'Content-Length': '12', 'Connection': 'keep-alive', 'x-pinecone-auth-rejected-reason': 'Malformed domain', 'www-authenticate': 'Malformed domain', 'server': 'envoy'})
# HTTP response body: Unauthorized
